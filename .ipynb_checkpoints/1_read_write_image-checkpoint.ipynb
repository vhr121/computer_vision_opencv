# %%
import cv2

# %%
img = cv2.imread('my_img.jpeg') #read an image

# %%
cv2.imshow('my_name',img) #show the image
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
mod_img=img*0.25

# %% [markdown]
# ##
